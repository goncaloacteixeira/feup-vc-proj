# %% [markdown]
# # Traffic sign detection and classification

# %%
from xml.dom import minidom
from os import walk
import pandas as pd
import cv2 as cv
import numpy as np
from sklearn import metrics
import os

# %%
filenames = next(walk("res/annotations"), (None, None, []))[2]  # [] if no file

signs = []

for annotation in filenames:
    # parse an xml file by name
    file = minidom.parse("res/annotations/" + annotation)

    #use getElementsByTagName() to get tag
    if len(file.getElementsByTagName('name')) == 1:
        path = "res/images/" + file.getElementsByTagName('filename')[0].firstChild.data
        filename = file.getElementsByTagName('filename')[0].firstChild.data
        name = file.getElementsByTagName('name')[0].firstChild.data
    # truncated = file.getElementsByTagName('truncated')[0].firstChild.data
    # occluded = file.getElementsByTagName('occluded')[0].firstChild.data
    # difficult = file.getElementsByTagName('difficult')[0].firstChild.data

    if name == "trafficlight":
        continue

    signs.append([filename, name, path])

print(f'Importing {len(signs)} images')

df = pd.DataFrame(signs, columns=['filename', 'name', 'path'])
# Out:
# Importing 818 images

# %%
def condition_classes(s):
    if s['name'] == 'speedlimit':
        return 0
    elif s["name"] == 'crosswalk':
        return 1
    elif s["name"] == "stop":
        return 2


df["class"] = df.apply(condition_classes, axis=1)

# %% [markdown]
# ## Step 1 - Histogram equalization
#
# TODO - Need to improve the histogram equalization

# %%
def apply_histogram_equalization(row):
    img = cv.imread(row.path)
    lab = cv.cvtColor(img, cv.COLOR_BGR2LAB)

    clahe = cv.createCLAHE(clipLimit=10.0,tileGridSize=(8,8))

    lab[...,0] = clahe.apply(lab[...,0])

    out = cv.cvtColor(lab, cv.COLOR_LAB2BGR)
    
    #para ignorar este passo 
    out = img

    cv.imwrite("output2/1histogram/" + row.filename, out)

# %%
df.apply(apply_histogram_equalization, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 813    None
# 814    None
# 815    None
# 816    None
# 817    None
# Length: 818, dtype: object

# %% [markdown]
# ## Step 2 - Segmentation by Color

# %%
def apply_segmentation(row):
    img = cv.imread(row.path)
    # TODO - work on histogram equalization
    img_hist = cv.imread("output2/1histogram/" + row.filename)
    img_hsv = cv.cvtColor(img_hist, cv.COLOR_BGR2HSV)

    lower_red_m1 = (0, 70, 60)
    upper_red_m1 = (10, 255, 255)

    lower_red_m2 = (170, 70, 60)
    upper_red_m2 = (180, 255, 255)

    lower_blue_m3 = (94, 127, 20)
    upper_blue_m3 = (126, 255, 200)

    mask1 = cv.inRange(img_hsv, lower_red_m1, upper_red_m1)
    mask2 = cv.inRange(img_hsv, lower_red_m2, upper_red_m2)
    blue_mask = cv.inRange(img_hsv, lower_blue_m3, upper_blue_m3)

    red_mask = mask1 + mask2

    # out = cv.bitwise_and(img_hist, img_hist, mask=mask)
    if cv.countNonZero(red_mask) !=0 :
        cv.imwrite("output2/2segmentation/red/" + row.filename, red_mask)
    if cv.countNonZero(blue_mask) != 0:
        cv.imwrite("output2/2segmentation/blue/" + row.filename, blue_mask)

# %%
df.apply(apply_segmentation, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 813    None
# 814    None
# 815    None
# 816    None
# 817    None
# Length: 818, dtype: object

# %% [markdown]
# ## Step 3 - Post-Processing

# %%
def compare_masks(blue, red): 
    return blue if red == np.zeros(red.shape) else (red if blue == np.zeros(blue.shape) else blue, red)

# %%
def apply_post_processing_blue(row):
    img = cv.imread(row.path)
    segm_img = cv.imread("output2/2segmentation/blue/" + row.filename, cv.IMREAD_GRAYSCALE)
    if cv.countNonZero(segm_img) == 0 :
        print(row)
        return

    linesP = cv.HoughLinesP(segm_img, 1, np.pi / 180, 50, None, 50, 10)

    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(segm_img, (l[0], l[1]), (l[2], l[3]),
                    (255, 0, 255), 3, cv.LINE_AA)

    # blue 
    # apply median filter to remove noise
    out = cv.medianBlur(segm_img, 5)
    rows, cols = out.shape

    # Taking a matrix of size 5 as the kernel
    kernel = np.ones((5, 5), np.uint8)

    # morphological operations
    out = cv.morphologyEx(out, cv.MORPH_CLOSE, kernel, iterations=4)

    # remove small and weird objects
    contours, hierarchy = cv.findContours(out, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)[-2:]
    for contour in contours:
        x, y, w, h = cv.boundingRect(contour)
        aspect_ratio = float(w) / h
        if cv.contourArea(contour) < 1 / 1500.0 * rows * cols and (aspect_ratio > 0.5 or aspect_ratio < 1.3):
            out = cv.fillPoly(out, pts=contour, color=(0, 0, 0))

    mask = np.full(img.shape, 0, "uint8")
    contours, hierarchies = cv.findContours(out, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)[-2:]
    for cnt in contours:
        cv.drawContours(mask, [cnt], -1, (255, 255, 255), -1)

    mask = cv.cvtColor(mask, cv.COLOR_BGR2GRAY)
    
    # morphological operations
    out = cv.erode(mask, kernel, iterations=1)
    out = cv.dilate(mask, kernel, iterations=5)

    cv.imwrite("output2/3post_processing/blue/" + row.filename, out)

# %%
df.apply(apply_post_processing_blue, axis=1)
# Out:
# filename                     road103.png
# name                          speedlimit
# path              res/images/road103.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 3, dtype: object
# filename                     road104.png
# name                          speedlimit
# path              res/images/road104.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 4, dtype: object
# filename                     road108.png
# name                          speedlimit
# path              res/images/road108.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 8, dtype: object
# filename                     road109.png
# name                          speedlimit
# path              res/images/road109.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 9, dtype: object
# filename                     road109.png
# name                          speedlimit
# path              res/images/road109.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 10, dtype: object
# filename                     road203.png
# name                          speedlimit
# path              res/images/road203.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 100, dtype: object
# filename                     road210.png
# name                          speedlimit
# path              res/images/road210.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 108, dtype: object
# filename                     road211.png
# name                          speedlimit
# path              res/images/road211.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 109, dtype: object
# filename                     road212.png
# name                          speedlimit
# path              res/images/road212.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 110, dtype: object
# filename                     road213.png
# name                          speedlimit
# path              res/images/road213.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 111, dtype: object
# filename                     road214.png
# name                          speedlimit
# path              res/images/road214.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 112, dtype: object
# filename                     road215.png
# name                          speedlimit
# path              res/images/road215.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 113, dtype: object
# filename                     road217.png
# name                          speedlimit
# path              res/images/road217.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 115, dtype: object
# filename                     road274.png
# name                          speedlimit
# path              res/images/road274.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 161, dtype: object
# filename                     road274.png
# name                          speedlimit
# path              res/images/road274.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 162, dtype: object
# filename                     road279.png
# name                          speedlimit
# path              res/images/road279.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 166, dtype: object
# filename                     road279.png
# name                          speedlimit
# path              res/images/road279.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 167, dtype: object
# filename                     road280.png
# name                          speedlimit
# path              res/images/road280.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 168, dtype: object
# filename                     road280.png
# name                          speedlimit
# path              res/images/road280.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 169, dtype: object
# filename                     road280.png
# name                          speedlimit
# path              res/images/road280.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 170, dtype: object
# filename                     road283.png
# name                          speedlimit
# path              res/images/road283.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 171, dtype: object
# filename                     road284.png
# name                          speedlimit
# path              res/images/road284.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 172, dtype: object
# filename                     road284.png
# name                          speedlimit
# path              res/images/road284.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 173, dtype: object
# filename                     road286.png
# name                          speedlimit
# path              res/images/road286.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 174, dtype: object
# filename                     road286.png
# name                          speedlimit
# path              res/images/road286.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 175, dtype: object
# filename                     road288.png
# name                          speedlimit
# path              res/images/road288.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 176, dtype: object
# filename                     road288.png
# name                          speedlimit
# path              res/images/road288.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 177, dtype: object
# filename                     road288.png
# name                          speedlimit
# path              res/images/road288.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 178, dtype: object
# filename                     road290.png
# name                          speedlimit
# path              res/images/road290.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 179, dtype: object
# filename                     road291.png
# name                          speedlimit
# path              res/images/road291.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 180, dtype: object
# filename                     road291.png
# name                          speedlimit
# path              res/images/road291.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 181, dtype: object
# filename                     road293.png
# name                          speedlimit
# path              res/images/road293.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 182, dtype: object
# filename                     road296.png
# name                          speedlimit
# path              res/images/road296.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 185, dtype: object
# filename                     road301.png
# name                          speedlimit
# path              res/images/road301.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 189, dtype: object
# filename                     road301.png
# name                          speedlimit
# path              res/images/road301.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 190, dtype: object
# filename                     road303.png
# name                                stop
# path              res/images/road303.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 191, dtype: object
# filename                     road320.png
# name                          speedlimit
# path              res/images/road320.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 209, dtype: object
# filename                     road320.png
# name                          speedlimit
# path              res/images/road320.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 210, dtype: object
# filename                     road326.png
# name                          speedlimit
# path              res/images/road326.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 215, dtype: object
# filename                     road326.png
# name                          speedlimit
# path              res/images/road326.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 216, dtype: object
# filename                     road332.png
# name                          speedlimit
# path              res/images/road332.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 221, dtype: object
# filename                     road334.png
# name                          speedlimit
# path              res/images/road334.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 223, dtype: object
# filename                     road335.png
# name                          speedlimit
# path              res/images/road335.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 224, dtype: object
# filename                     road338.png
# name                          speedlimit
# path              res/images/road338.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 227, dtype: object
# filename                     road340.png
# name                          speedlimit
# path              res/images/road340.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 229, dtype: object
# filename                     road340.png
# name                          speedlimit
# path              res/images/road340.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 230, dtype: object
# filename                     road344.png
# name                          speedlimit
# path              res/images/road344.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 233, dtype: object
# filename                     road345.png
# name                          speedlimit
# path              res/images/road345.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 234, dtype: object
# filename                     road349.png
# name                          speedlimit
# path              res/images/road349.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 238, dtype: object
# filename                     road352.png
# name                          speedlimit
# path              res/images/road352.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 241, dtype: object
# filename                     road360.png
# name                          speedlimit
# path              res/images/road360.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 250, dtype: object
# filename                     road360.png
# name                          speedlimit
# path              res/images/road360.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 251, dtype: object
# filename                     road363.png
# name                          speedlimit
# path              res/images/road363.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 253, dtype: object
# filename                     road364.png
# name                          speedlimit
# path              res/images/road364.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 254, dtype: object
# filename                     road365.png
# name                          speedlimit
# path              res/images/road365.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 255, dtype: object
# filename                     road366.png
# name                          speedlimit
# path              res/images/road366.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 256, dtype: object
# filename                     road366.png
# name                          speedlimit
# path              res/images/road366.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 257, dtype: object
# filename                     road368.png
# name                          speedlimit
# path              res/images/road368.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 258, dtype: object
# filename                     road369.png
# name                          speedlimit
# path              res/images/road369.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 259, dtype: object
# filename                     road370.png
# name                          speedlimit
# path              res/images/road370.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 260, dtype: object
# filename                     road371.png
# name                          speedlimit
# path              res/images/road371.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 261, dtype: object
# filename                     road372.png
# name                          speedlimit
# path              res/images/road372.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 262, dtype: object
# filename                     road373.png
# name                          speedlimit
# path              res/images/road373.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 263, dtype: object
# filename                     road374.png
# name                                stop
# path              res/images/road374.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 264, dtype: object
# filename                     road375.png
# name                          speedlimit
# path              res/images/road375.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 265, dtype: object
# filename                     road377.png
# name                          speedlimit
# path              res/images/road377.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 267, dtype: object
# filename                     road52.png
# name                               stop
# path              res/images/road52.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 412, dtype: object
# filename                     road54.png
# name                               stop
# path              res/images/road54.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 434, dtype: object
# filename                     road56.png
# name                               stop
# path              res/images/road56.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 456, dtype: object
# filename                     road56.png
# name                               stop
# path              res/images/road56.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 457, dtype: object
# filename                     road56.png
# name                               stop
# path              res/images/road56.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 458, dtype: object
# filename                     road56.png
# name                               stop
# path              res/images/road56.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 459, dtype: object
# filename                     road56.png
# name                               stop
# path              res/images/road56.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 460, dtype: object
# filename                     road56.png
# name                               stop
# path              res/images/road56.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 461, dtype: object
# filename                     road60.png
# name                               stop
# path              res/images/road60.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 500, dtype: object
# filename                     road61.png
# name                               stop
# path              res/images/road61.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 511, dtype: object
# filename                     road62.png
# name                               stop
# path              res/images/road62.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 522, dtype: object
# filename                     road631.png
# name                                stop
# path              res/images/road631.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 535, dtype: object
# filename                     road634.png
# name                                stop
# path              res/images/road634.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 538, dtype: object
# filename                     road635.png
# name                                stop
# path              res/images/road635.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 539, dtype: object
# filename                     road636.png
# name                                stop
# path              res/images/road636.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 540, dtype: object
# filename                     road637.png
# name                                stop
# path              res/images/road637.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 541, dtype: object
# filename                     road637.png
# name                                stop
# path              res/images/road637.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 542, dtype: object
# filename                     road637.png
# name                                stop
# path              res/images/road637.png
# class                                  2
# shapes                                []
# classification                        -1
# Name: 543, dtype: object
# filename                     road64.png
# name                               stop
# path              res/images/road64.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 544, dtype: object
# filename                     road64.png
# name                               stop
# path              res/images/road64.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 545, dtype: object
# filename                     road641.png
# name                          speedlimit
# path              res/images/road641.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 546, dtype: object
# filename                     road642.png
# name                          speedlimit
# path              res/images/road642.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 547, dtype: object
# filename                     road643.png
# name                          speedlimit
# path              res/images/road643.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 548, dtype: object
# filename                     road660.png
# name                          speedlimit
# path              res/images/road660.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 567, dtype: object
# filename                     road661.png
# name                          speedlimit
# path              res/images/road661.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 568, dtype: object
# filename                     road662.png
# name                          speedlimit
# path              res/images/road662.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 569, dtype: object
# filename                     road663.png
# name                          speedlimit
# path              res/images/road663.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 570, dtype: object
# filename                     road664.png
# name                          speedlimit
# path              res/images/road664.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 571, dtype: object
# filename                     road665.png
# name                          speedlimit
# path              res/images/road665.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 572, dtype: object
# filename                     road666.png
# name                          speedlimit
# path              res/images/road666.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 573, dtype: object
# filename                     road68.png
# name                               stop
# path              res/images/road68.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 588, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 621, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 622, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 623, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 624, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 625, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 626, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 627, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 628, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 629, dtype: object
# filename                     road71.png
# name                               stop
# path              res/images/road71.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 630, dtype: object
# filename                     road722.png
# name                          speedlimit
# path              res/images/road722.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 635, dtype: object
# filename                     road723.png
# name                          speedlimit
# path              res/images/road723.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 636, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 654, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 655, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 656, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 657, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 658, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 659, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 660, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 661, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 662, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 663, dtype: object
# filename                     road74.png
# name                               stop
# path              res/images/road74.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 664, dtype: object
# filename                     road76.png
# name                               stop
# path              res/images/road76.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 676, dtype: object
# filename                     road77.png
# name                               stop
# path              res/images/road77.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 687, dtype: object
# filename                     road788.png
# name                          speedlimit
# path              res/images/road788.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 707, dtype: object
# filename                     road79.png
# name                               stop
# path              res/images/road79.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 709, dtype: object
# filename                     road79.png
# name                               stop
# path              res/images/road79.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 710, dtype: object
# filename                     road79.png
# name                               stop
# path              res/images/road79.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 711, dtype: object
# filename                     road79.png
# name                               stop
# path              res/images/road79.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 712, dtype: object
# filename                     road79.png
# name                               stop
# path              res/images/road79.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 713, dtype: object
# filename                     road79.png
# name                               stop
# path              res/images/road79.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 714, dtype: object
# filename                     road80.png
# name                               stop
# path              res/images/road80.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 721, dtype: object
# filename                     road800.png
# name                          speedlimit
# path              res/images/road800.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 722, dtype: object
# filename                     road81.png
# name                               stop
# path              res/images/road81.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 732, dtype: object
# filename                     road817.png
# name                          speedlimit
# path              res/images/road817.png
# class                                  0
# shapes                                []
# classification                        -1
# Name: 740, dtype: object
# filename                     road82.png
# name                               stop
# path              res/images/road82.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 743, dtype: object
# filename                     road82.png
# name                               stop
# path              res/images/road82.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 744, dtype: object
# filename                     road82.png
# name                               stop
# path              res/images/road82.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 745, dtype: object
# filename                     road82.png
# name                               stop
# path              res/images/road82.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 746, dtype: object
# filename                     road82.png
# name                               stop
# path              res/images/road82.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 747, dtype: object
# filename                     road82.png
# name                               stop
# path              res/images/road82.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 748, dtype: object
# filename                     road82.png
# name                               stop
# path              res/images/road82.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 749, dtype: object
# filename                     road82.png
# name                               stop
# path              res/images/road82.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 750, dtype: object
# filename                     road83.png
# name                               stop
# path              res/images/road83.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 754, dtype: object
# filename                     road87.png
# name                               stop
# path              res/images/road87.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 798, dtype: object
# filename                     road88.png
# name                               stop
# path              res/images/road88.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 806, dtype: object
# filename                     road90.png
# name                               stop
# path              res/images/road90.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 808, dtype: object
# filename                     road94.png
# name                               stop
# path              res/images/road94.png
# class                                 2
# shapes                               []
# classification                       -1
# Name: 812, dtype: object
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 813    None
# 814    None
# 815    None
# 816    None
# 817    None
# Length: 818, dtype: object

# %%
# def apply_post_processing(row):
#     img = cv.imread(row.path)
#     blue_segm_img = cv.imread(
#         "output2/2segmentation/blue/" + row.filename, cv.IMREAD_GRAYSCALE)
#     red_segm_img = cv.imread(
#         "output2/2segmentation/red/" + row.filename, cv.IMREAD_GRAYSCALE)


#     # blue
#     # apply median filter to remove noise
#     out = cv.medianBlur(segm_img, 5)
#     rows, cols = out.shape

#     # Taking a matrix of size 5 as the kernel
#     kernel = np.ones((5, 5), np.uint8)

#     # morphological operations
#     out = cv.morphologyEx(out, cv.MORPH_CLOSE, kernel, iterations=4)

#     # remove small and weird objects
#     contours, hierarchy = cv.findContours(
#         out, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)[-2:]
#     for contour in contours:
#         x, y, w, h = cv.boundingRect(contour)
#         aspect_ratio = float(w) / h
#         if cv.contourArea(contour) < 1 / 1500.0 * rows * cols and (aspect_ratio > 0.5 or aspect_ratio < 1.3):
#             out = cv.fillPoly(out, pts=contour, color=(0, 0, 0))

#     mask = np.full(img.shape, 0, "uint8")
#     contours, hierarchies = cv.findContours(
#         out, cv.RETR_TREE, cv.CHAIN_APPROX_NONE)[-2:]
#     for cnt in contours:
#         cv.drawContours(mask, [cnt], -1, (255, 255, 255), -1)

#     mask = cv.cvtColor(mask, cv.COLOR_BGR2GRAY)
#     # morphological operations
#     out = cv.erode(mask, kernel, iterations=1)
#     out = cv.dilate(mask, kernel, iterations=1)

#     cv.imwrite("output2/3post_processing/" + row.filename, out)

# %%
# df.apply(apply_post_processing, axis=1);

# %% [markdown]
# ## Step 4 - Shape Recognition

# %%
## TODO MERGE DAS SHAPES DAS ROWS 
## IR AS DUAS PASTAS E FAZER append das shapes que dão

def shape_recognition(row):
    img = cv.imread(row.path)
    processed = cv.imread("output2/3post_processing/blue/" + row.filename, 0)

    _, thresh = cv.threshold(processed, 240, 255, cv.CHAIN_APPROX_SIMPLE)
    contours, _ = cv.findContours(
        thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)[-2:]

    contours = sorted(contours, key=lambda x: -cv.contourArea(x))[:10]

    shapes = []

    for contour in contours:
        if float(cv.contourArea(contour) / (img.shape[0]*img.shape[1])) >= 0.95:
            continue
        approx = cv.approxPolyDP(contour, 0.01*cv.arcLength(contour, True), True)
        if len(approx) == 4:
            shapes.append(("rectangle", cv.contourArea(contour), (cv.boundingRect(contour))))
        elif len(approx) == 8:
            shapes.append(("octagon", cv.contourArea(contour), (cv.boundingRect(contour))))
        elif len(approx) > 8:
            shapes.append(("circle", cv.contourArea(contour), (cv.boundingRect(contour))))

    return shapes

# %%
df["shapes"] = df.apply(shape_recognition, axis=1);

# %%
def classify(row):
    shapes_info = row.shapes
    if len(shapes_info) == 0:
        return -1

    shapes = [x[0] for x in shapes_info]
    shape = shapes[0]

    if shape == 'circle':
        return 0
    elif shape == 'rectangle':
        return 1
    elif shape == 'octagon':
        return 2

    return -1

df["classification"] = df.apply(classify, axis=1);

# %%
def concatenate_and_write(row):
    img = cv.imread(row.path)
    #hist = cv.imread("output2/1histogram/red/" + row.filename)
    hist = img
    segm = cv.imread("output2/2segmentation/blue/" + row.filename)
    post = cv.imread("output2/3post_processing/blue/" + row.filename)
    vis = np.concatenate((img, hist, segm, post), axis=1)

    result = "right" if row['class'] == row['classification'] else "wrong"

    c = df['class'][row.name]
    p = os.path.join("output2", "4concatenated", "blue",
                     f'classe{c}', result + "_" + row.filename)

    cv.imwrite(p, vis)

# %%
df.apply(concatenate_and_write, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 813    None
# 814    None
# 815    None
# 816    None
# 817    None
# Length: 818, dtype: object

# %% [markdown]
# ## Results

# %%
df_found = df[df["classification"] != -1]

accuracy_total = metrics.accuracy_score(df["class"], df["classification"])
accuracy_found = metrics.accuracy_score(df_found["class"], df_found["classification"])

print("Classes:\n", df["class"].value_counts())
print("Detected classes:\n", df["classification"].value_counts())
print("Accuracy Total: {:.02f}%".format(accuracy_total*100))
print("Accuracy Signs Found: {:.02f}%".format(accuracy_found*100))
# Out:
# Classes:
#  0    620
# 2    145
# 1     53
# Name: class, dtype: int64
# Detected classes:
#   0    377
# -1    336
#  2     53
#  1     52
# Name: classification, dtype: int64
# Accuracy Total: 45.11%
# Accuracy Signs Found: 76.56%

# %%
failed_0 = len(df[(df["class"] == 0) & (df["classification"] != 0)])    # speedlimit
failed_1 = len(df[(df["class"] == 1) & (df["classification"] != 1)])    # crosswalk
failed_2 = len(df[(df["class"] == 2) & (df["classification"] != 2)])    # stop

failed_1_0 = len(df[(df["class"] == 1) & (df["classification"] == 0)])
failed_1_2 = len(df[(df["class"] == 1) & (df["classification"] == 2)])

right_0 = len(df[(df["class"] == 0) & (df["classification"] == 0)])
right_1 = len(df[(df["class"] == 1) & (df["classification"] == 1)])
right_2 = len(df[(df["class"] == 2) & (df["classification"] == 2)])

not_classified_0 = len(df[(df["class"] == 0) & (df["classification"] == -1)])
not_classified_1 = len(df[(df["class"] == 1) & (df["classification"] == -1)])
not_classified_2 = len(df[(df["class"] == 2) & (df["classification"] == -1)])

print("Class 0 - SpeedLimit: R:{}|W:{}|NC:{}".format(right_0, failed_0, not_classified_0))
print("Class 1 - Crosswalk: R:{}|W:{}|NC:{}|0:{}|2:{}".format(right_1, failed_1, not_classified_1, failed_1_0,failed_1_2))
print("Class 2 - Stop: R:{}|W:{}|NC:{}".format(right_2, failed_2, not_classified_2))
# Out:
# Class 0 - SpeedLimit: R:297|W:323|NC:227
# Class 1 - Crosswalk: R:16|W:37|NC:19|0:12|2:6
# Class 2 - Stop: R:0|W:145|NC:126

# %%
def apply_post_processing_blue(img):
    segm_img = cv.imread("output2\\2segmentation\\blue\\road140.png", 0)
    cv.imshow("out", segm_img)
    cv.waitKey(0)
    cv.destroyWindow("out")

    linesP = cv.HoughLinesP(segm_img, 1, np.pi / 180, 50, None, 60, 20)

    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(segm_img, (l[0], l[1]), (l[2], l[3]),
                    (255, 0, 255), 3, cv.LINE_AA)
   
    # blue
    # apply median filter to remove noise
    out = cv.medianBlur(segm_img, 5)
    
    cv.imshow("blur", out)
    cv.waitKey(0)
    cv.destroyWindow("blur")

    rows, cols = out.shape

    # Taking a matrix of size 5 as the kernel
    kernel = np.ones((5, 5), np.uint8)

    # morphological operations
    out = cv.morphologyEx(out, cv.MORPH_CLOSE, kernel, iterations=4)


    # remove small and weird objects
    contours, hierarchy = cv.findContours(
        out, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)[-2:]
    for contour in contours:
        x, y, w, h = cv.boundingRect(contour)
        aspect_ratio = float(w) / h
        if cv.contourArea(contour) < 1 / 1500.0 * rows * cols and (aspect_ratio > 0.5 or aspect_ratio < 1.3):
            out = cv.fillPoly(out, pts=contour, color=(0, 0, 0))

    cv.imshow("out", out)
    cv.waitKey(0)
    cv.destroyWindow("out")

    mask = np.full(segm_img.shape, 0, "uint8")
    contours, hierarchies = cv.findContours(
        out, cv.RETR_TREE, cv.CHAIN_APPROX_NONE)[-2:]
    for cnt in contours:
        cv.drawContours(mask, [cnt], -1, (255, 255, 255), -1)


    # morphological operations
    out = cv.erode(mask, kernel, iterations=1)
    out = cv.dilate(mask, kernel, iterations=6)

    cv.imshow("out", out)
    cv.waitKey(0)
    cv.destroyWindow("out")

    cv.imwrite("output2/3post_processing/blue/road140.png", out)


apply_post_processing_blue("ss")

# %%
def shape_recognition():
    processed = cv.imread("output2/3post_processing/blue/road140.png", 0)
    cv.imshow("out", processed)
    cv.waitKey(0)
    cv.destroyWindow("out")


    _, thresh = cv.threshold(processed, 240, 255, cv.CHAIN_APPROX_SIMPLE)
    contours, _ = cv.findContours(
        thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)[-2:]

    contours = sorted(contours, key=lambda x: -cv.contourArea(x))[:10]

    shapes = []

    for contour in contours:
        if float(cv.contourArea(contour) / (processed.shape[0]*processed.shape[1])) >= 0.95:
            continue
        approx = cv.approxPolyDP(
            contour, 0.01*cv.arcLength(contour, True), True)
        cv.drawContours(processed, [contour], 0, (128, 0, 255), 2)
        print(len(approx))
        cv.imshow("out", processed)
        cv.waitKey(0)
        cv.destroyWindow("out")
        
        if len(approx) == 4:
            shapes.append(("rectangle", cv.contourArea(
                contour), (cv.boundingRect(contour))))
        elif len(approx) == 8:
            shapes.append(("octagon", cv.contourArea(
                contour), (cv.boundingRect(contour))))
        elif len(approx) > 8:
            shapes.append(("circle", cv.contourArea(
                contour), (cv.boundingRect(contour))))

    return shapes

shape_recognition()
# Out:
# 10
# 6
# 11
# 5
# 4
# [('circle', 5697.0, (292, 132, 69, 109)),
#  ('circle', 3232.0, (209, 163, 70, 62)),
#  ('rectangle', 312.0, (386, 214, 14, 25))]
