# %% [markdown]
# # Traffic sign detection and classification

# %%
from xml.dom import minidom
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
train = []
test = []

with open("test.txt") as _file:
    for line in _file:
        train.append(line.replace('\n', ''))

# noinspection JupyterPackage
with open("train.txt") as _file:
    for line in _file:
        test.append(line.replace('\n', ''))

def create_dataframe(data):
    signs = []
    for name in data:
        file = minidom.parse("annotations/" + name + ".xml")
        path = "images/" + file.getElementsByTagName('filename')[0].firstChild.data
        filename = file.getElementsByTagName('filename')[0].firstChild.data
        name = file.getElementsByTagName('name')
        classes = []
        for n in name:
            classes.append(n.firstChild.data)
        number_of_signs = len(classes)

        signs.append([filename, " ".join(classes), path, number_of_signs])

    return pd.DataFrame(signs, columns=['filename', 'classes', 'path', 'number_of_signs'])

df_train = create_dataframe(train)
df_test = create_dataframe(test)

# %% [markdown]
# ## Pre-Trained Model RestNet34 on ImageNet dataset.

# %%
from fastai.vision.all import *

bs = 64
batch_tfms = aug_transforms(max_lighting=0.1, max_zoom=1.05, max_warp=0.)
item_tfms = [ Resize((200, 200), method='squish')]

datablock = DataBlock(blocks=(ImageBlock, MultiCategoryBlock),
                   get_x=ColReader(0, pref='images/'),
                   splitter=RandomSplitter(),
                   get_y=ColReader(1, label_delim=' '),
                   item_tfms = item_tfms)

dls_train = datablock.dataloaders(df_train, bs=bs)
dls_test = dls_train.test_dl(df_test, with_labels=True, bs=bs)

dls_train.show_batch(max_n=9, figsize=(12,9))

# %%
f1_macro = F1ScoreMulti(thresh=0.5, average='macro')
f1_macro.name = 'F1(macro)'
f1_samples = F1ScoreMulti(thresh=0.5, average='samples')
f1_samples.name = 'F1(samples)'
learn = vision_learner(dls_train, resnet50, pretrained=True, metrics=[partial(accuracy_multi, thresh=0.5), f1_macro, f1_samples])

learn.loss_func = BCEWithLogitsLossFlat()

learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0005754399462603033)

# %%
lr = 3e-2
learn = learn.to_fp16()

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>F1(macro)</th>
#       <th>F1(samples)</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.035307</td>
#       <td>5.809704</td>
#       <td>0.312500</td>
#       <td>0.305537</td>
#       <td>0.294231</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.812801</td>
#       <td>5.574652</td>
#       <td>0.307692</td>
#       <td>0.369604</td>
#       <td>0.387179</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.604083</td>
#       <td>2.079588</td>
#       <td>0.466346</td>
#       <td>0.395741</td>
#       <td>0.435897</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.473889</td>
#       <td>0.735649</td>
#       <td>0.764423</td>
#       <td>0.574171</td>
#       <td>0.675000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.386714</td>
#       <td>0.349095</td>
#       <td>0.855769</td>
#       <td>0.647755</td>
#       <td>0.787821</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')
# Out:
# Path('models/stage-1.pth')

# %%
learn.unfreeze()
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=5.248074739938602e-05)

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>F1(macro)</th>
#       <th>F1(samples)</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.066509</td>
#       <td>0.269932</td>
#       <td>0.899038</td>
#       <td>0.730150</td>
#       <td>0.851923</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.076502</td>
#       <td>0.352886</td>
#       <td>0.875000</td>
#       <td>0.693720</td>
#       <td>0.816667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.079419</td>
#       <td>0.253617</td>
#       <td>0.947115</td>
#       <td>0.822403</td>
#       <td>0.910256</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.069392</td>
#       <td>0.181816</td>
#       <td>0.942308</td>
#       <td>0.811987</td>
#       <td>0.903846</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.060822</td>
#       <td>0.160293</td>
#       <td>0.942308</td>
#       <td>0.805879</td>
#       <td>0.913462</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_top_losses(9);
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>predicted</th>
#       <th>probabilities</th>
#       <th>loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>crosswalk;speedlimit</td>
#       <td>speedlimit</td>
#       <td>TensorBase([1.3045e-03, 9.9969e-01, 3.7801e-03, 1.1683e-04])</td>
#       <td>1.6615391969680786</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>crosswalk</td>
#       <td>speedlimit</td>
#       <td>TensorBase([0.0318, 0.9451, 0.0042, 0.0084])</td>
#       <td>1.592153787612915</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>speedlimit</td>
#       <td>crosswalk;speedlimit;trafficlight</td>
#       <td>TensorBase([0.5578, 0.9994, 0.0108, 0.9780])</td>
#       <td>1.1605396270751953</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>crosswalk;speedlimit</td>
#       <td>speedlimit</td>
#       <td>TensorBase([0.0382, 0.9999, 0.0017, 0.0086])</td>
#       <td>0.8185373544692993</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>stop</td>
#       <td>speedlimit</td>
#       <td>TensorBase([0.0134, 0.5766, 0.1522, 0.0010])</td>
#       <td>0.6894397735595703</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>crosswalk;speedlimit</td>
#       <td>speedlimit</td>
#       <td>TensorBase([1.1717e-01, 9.9988e-01, 1.2528e-02, 1.5356e-04])</td>
#       <td>0.5392573475837708</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>crosswalk;speedlimit</td>
#       <td>speedlimit</td>
#       <td>TensorBase([0.3384, 0.5410, 0.0960, 0.0014])</td>
#       <td>0.45009174942970276</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>speedlimit</td>
#       <td>crosswalk;speedlimit</td>
#       <td>TensorBase([6.1722e-01, 9.6892e-01, 1.3020e-02, 6.8149e-05])</td>
#       <td>0.2508352994918823</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>trafficlight</td>
#       <td>stop;trafficlight</td>
#       <td>TensorBase([2.6324e-04, 2.8054e-11, 5.7505e-01, 1.0000e+00])</td>
#       <td>0.21408292651176453</td>
#     </tr>
#   </tbody>
# </table>

# %%
loss, acc, _, _ = learn.validate(dl=dls_test)

print(f'Loss: {loss}, Accuracy: {acc*100} %')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 0.45495057106018066, Accuracy: 88.58075141906738 %
